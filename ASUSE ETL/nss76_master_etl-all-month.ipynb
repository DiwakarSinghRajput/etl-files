# %%
import pandas as pd
import configparser as cp
import psycopg2
from openpyxl.utils import column_index_from_string
from openpyxl.utils import get_column_letter

# %%
config = cp.RawConfigParser()
config_files = ['ASUSE-2025/Table-2.properties']


print(config_files)
# Out:
# ['ASUSE-2025/Table-2.properties']

# %%
#read property file

for file in config_files:
    print('Currently Read File  :- ' + file)
    config.read(file)

    
    ip = config.get('database_details', 'database.ip')
    port = config.get('database_details', 'database.port')
    username = config.get('database_details', 'database.username')
    password = config.get('database_details', 'database.password')
    dbname = config.get('database_details', 'database.dbname')
    tablename = config.get('database_details', 'database.tablename')


    
    connection = psycopg2.connect(database=dbname, user=username, password=password, host=ip, port=port)
    cursor = connection.cursor()
    
    sheet_location = config.get('master_properties', 'sheet_path')
    print('reading excel file:',sheet_location)
    
    
    
    #read property env.tables.unique.sheets and start the nested loops
    unique_sheet_count = int(config.get('tables_for_etl', 'etl.tables.unique.sheets'))
    
    #below loop for unique sheets only
    for i in range(unique_sheet_count):
        print('Starting for i(Unique Sheets Count):',i)
        #run below loop for blocks that are split across sheets for "each" unique sheet
        block_count = int(config.get('tables_for_etl', 'etl.tables.table.'+str(i+1)+'.block.count'))
       
    
        
        for j in range(block_count):
            # skipCellAfter =  int(config.get('tables_for_etl', 'etl.tables.table.'+str(i+1)+'.block.skipCellAfter'))
            # skipNoOfCell =  int(config.get('tables_for_etl', 'etl.tables.table.'+str(i+1)+'.block.skipNoOfCell'))
            header_names = config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.header.names').split(',')
            row_seggregation_level = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.rows.seggregation.level.count'))
            col_seggregation_level = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.level.count'))
            row_start = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.row.start'))
            row_end = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.row.end'))
            col_start = column_index_from_string(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.col.start'))
            col_end = column_index_from_string(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.col.end'))
        
            row_seggregation_foreign_list = []
            row_seggregation_foreignValue_list = []

            col_seggregation_foreign_list = []
            col_seggregation_loopValue_list = []
            col_seggregation_repeteAfter_list = []
            col_seggregation_foreignValue_list = []
            
            for k in range(int(row_seggregation_level)):
                row_seggregation_foreign_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.rows.seggregation.'+str(k+1)+'.foreign'))
                row_seggregation_foreignValue_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.rows.seggregation.'+str(k+1)+'.foreignValue'))
            
            
            for l in range(int(col_seggregation_level)):
                col_seggregation_foreign_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.foreign'))
                col_seggregation_loopValue_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.loopValue'))
                col_seggregation_repeteAfter_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.totalRows'))
                col_seggregation_foreignValue_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.foreignValue'))





            header_values = config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.sheet.header.values').split(',')
            sheet_name = config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.sheet')
            input_df = pd.read_excel(sheet_location,sheet_name)

            print('Read Excel Sheet:',sheet_name)
            for row in range(row_start-2,row_end-1):
                for col in range(col_start-1,col_end):

                    base = (row + 2) - row_start

                    # if base == 0 or not (base >= 16 and (base - 16) % 18 in (0, 1)):
                        

                    insert_query_prefix = "insert into " + tablename + "("+""
                    insert_query_suffix = " values("+"'"

                    
                    for o in range(len(header_names)):
                        insert_query_prefix = insert_query_prefix + header_names[o] +","
                        insert_query_suffix = insert_query_suffix + header_values[o]+"','"

                    col_seggregation_foreignValue_list = [
                        x.split(",") if isinstance(x, str) else x
                        for x in col_seggregation_foreignValue_list
                    ]


                    row_seggregation_foreignValue_list = [
                        x.split(",") if isinstance(x, str) else x
                        for x in row_seggregation_foreignValue_list
                    ]

                    
                    for m in range(len(col_seggregation_foreign_list)):

                        insert_query_prefix += col_seggregation_foreign_list[m] + ","

                        repeat = int(col_seggregation_repeteAfter_list[m])
                        loop = int(col_seggregation_loopValue_list[m])
                        

                        # if m == 0:
                        #     new_val = base // repeat

                        # elif m == 1:
                        #     new_val_1 = (base // repeat)
                        #     new_val =  (base //  int(col_seggregation_loopValue_list[m])) - ((int(col_seggregation_repeteAfter_list[m])//int(col_seggregation_loopValue_list[m])) * new_val_1)
                            
                        # elif m == 2:
                        #     new_val_1 = (base // repeat)
                        #     new_val =  (base //  int(col_seggregation_loopValue_list[m])) - ((int(col_seggregation_repeteAfter_list[m])//int(col_seggregation_loopValue_list[m])) * new_val_1)

                        if m == 0:
                            new_val = base % loop

                        
                        values_list = col_seggregation_foreignValue_list[m]

                        if new_val < len(values_list):
                            insert_query_suffix += values_list[new_val] + "','"
                        else:
                            insert_query_suffix += "NULL','"   # safety
                    
                                    
                    
                    indicator_val = input_df.iloc[row].values[col]

                    if indicator_val == 'x':
                        print('skipping, indicator_val['+str(row+2)+']['+str(get_column_letter(col+1))+']:',indicator_val)

                    for m in range(len(row_seggregation_foreign_list)):
                        insert_query_prefix += row_seggregation_foreign_list[m] + ","
                        values = row_seggregation_foreignValue_list[m][col - (col_start-1)]
                        insert_query_suffix += values + "','"

                        # month_code = row_seggregation_foreignValue_list[0][col - 4]
                
                    # print('Inserting, indicator_val['+str(row+2)+']['+str(get_column_letter(col+1))+']:',indicator_val)
    
    
                    insert_query_prefix = insert_query_prefix  +"indicator_value,"
                    insert_query_suffix = insert_query_suffix + str(indicator_val)+"','"

                    # insert_query_prefix = insert_query_prefix  +"month_code,"
                    # insert_query_suffix = insert_query_suffix + month_code+"','"
    
                    insert_query_prefix = insert_query_prefix  +"created_by,"
                    insert_query_suffix = insert_query_suffix + 'system' +"','"
                    insert_query_prefix = insert_query_prefix  +"updated_by,"
                    insert_query_suffix = insert_query_suffix + ' system' +"','"
    
                    from datetime import datetime

                    # insert_query_prefix = insert_query_prefix  +"year,"
                    # insert_query_suffix = insert_query_suffix + sheet_year +"','"
                    timestamp = datetime.now().strftime("%Y%m%d%H%M%S%f")
    
                    fact_code = f"asuse_{sheet_name}_{row+2}_{get_column_letter(col+1)}_{indicator_val}_{timestamp}"
                    # nfhs_fact_code = f"nss76_{sheet_name}_{row+2}_{get_column_letter(col+1)}_{indicator_val}"
                    fact_code = fact_code.replace(' ', '')
                    insert_query_prefix = insert_query_prefix + "asuse_fact_code)"
                    insert_query_suffix = insert_query_suffix + fact_code+"')"
    
                    final_query = insert_query_prefix+insert_query_suffix
                    print(final_query)
                    cursor.execute(final_query)
                    
                    connection.commit()


connection.close()
print('Data insert successfully')
# Out:
# Currently Read File  :- ASUSE-2025/Table-2.properties
# reading excel file: D:\Others\diwakar\etl-files\ASUSE ETL\ASUSE-2025\Tables - ASUSE 2025\Table-2.xlsx
# Starting for i(Unique Sheets Count): 0
# Read Excel Sheet: Sheet1
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','1','10411','system',' system','asuse_Sheet1_8_B_10411_20260611131334518775')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','2','62','system',' system','asuse_Sheet1_8_C_62_20260611131334565835')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','3','119','system',' system','asuse_Sheet1_8_D_119_20260611131334574846')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','1','2939','system',' system','asuse_Sheet1_9_B_2939_20260611131334585055')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','2','0','system',' system','asuse_Sheet1_9_C_0_20260611131334593341')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','3','2','system',' system','asuse_Sheet1_9_D_2_20260611131334604383')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','1','7350','system',' system','asuse_Sheet1_10_B_7350_20260611131334614544')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','2','1','system',' system','asuse_Sheet1_10_C_1_20260611131334625347')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','3','11','system',' system','asuse_Sheet1_10_D_11_20260611131334637164')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','1','15507','system',' system','asuse_Sheet1_11_B_15507_20260611131334649156')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','2','35','system',' system','asuse_Sheet1_11_C_35_20260611131334658511')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','3','102','system',' system','asuse_Sheet1_11_D_102_20260611131334670546')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','1','11492','system',' system','asuse_Sheet1_12_B_11492_20260611131334679361')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','2','146','system',' system','asuse_Sheet1_12_C_146_20260611131334687397')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','3','216','system',' system','asuse_Sheet1_12_D_216_20260611131334698251')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','1','417','system',' system','asuse_Sheet1_13_B_417_20260611131334709299')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','2','8','system',' system','asuse_Sheet1_13_C_8_20260611131334720308')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','3','20','system',' system','asuse_Sheet1_13_D_20_20260611131334730677')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','1','317','system',' system','asuse_Sheet1_14_B_317_20260611131334739704')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','2','1','system',' system','asuse_Sheet1_14_C_1_20260611131334749299')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','3','10','system',' system','asuse_Sheet1_14_D_10_20260611131334759719')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','1','16813','system',' system','asuse_Sheet1_15_B_16813_20260611131334770135')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','2','177','system',' system','asuse_Sheet1_15_C_177_20260611131334780449')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','3','531','system',' system','asuse_Sheet1_15_D_531_20260611131334790706')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','1','9380','system',' system','asuse_Sheet1_16_B_9380_20260611131334801808')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','2','172','system',' system','asuse_Sheet1_16_C_172_20260611131334810539')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','3','223','system',' system','asuse_Sheet1_16_D_223_20260611131334819784')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','1','4449','system',' system','asuse_Sheet1_17_B_4449_20260611131334829847')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','2','119','system',' system','asuse_Sheet1_17_C_119_20260611131334841364')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','3','239','system',' system','asuse_Sheet1_17_D_239_20260611131334852153')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','1','11424','system',' system','asuse_Sheet1_18_B_11424_20260611131334863517')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','2','29','system',' system','asuse_Sheet1_18_C_29_20260611131334872453')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','3','118','system',' system','asuse_Sheet1_18_D_118_20260611131334883209')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','1','12515','system',' system','asuse_Sheet1_19_B_12515_20260611131334893782')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','2','97','system',' system','asuse_Sheet1_19_C_97_20260611131334903681')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','3','270','system',' system','asuse_Sheet1_19_D_270_20260611131334912661')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','1','18348','system',' system','asuse_Sheet1_20_B_18348_20260611131334922302')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','2','257','system',' system','asuse_Sheet1_20_C_257_20260611131334933469')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','3','136','system',' system','asuse_Sheet1_20_D_136_20260611131334943091')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','1','20465','system',' system','asuse_Sheet1_21_B_20465_20260611131334955314')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','2','100','system',' system','asuse_Sheet1_21_C_100_20260611131334971986')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','3','208','system',' system','asuse_Sheet1_21_D_208_20260611131334982894')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','15','1','17556','system',' system','asuse_Sheet1_22_B_17556_20260611131334990892')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','15','2','343','system',' system','asuse_Sheet1_22_C_343_20260611131334998893')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','15','3','879','system',' system','asuse_Sheet1_22_D_879_20260611131335007892')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','16','1','2345','system',' system','asuse_Sheet1_23_B_2345_20260611131335017907')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','16','2','0','system',' system','asuse_Sheet1_23_C_0_20260611131335027030')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','16','3','2','system',' system','asuse_Sheet1_23_D_2_20260611131335038893')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','17','1','4495','system',' system','asuse_Sheet1_24_B_4495_20260611131335050028')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','17','2','9','system',' system','asuse_Sheet1_24_C_9_20260611131335059969')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','17','3','3','system',' system','asuse_Sheet1_24_D_3_20260611131335070360')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','18','1','685','system',' system','asuse_Sheet1_25_B_685_20260611131335080384')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','18','2','0','system',' system','asuse_Sheet1_25_C_0_20260611131335090815')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','18','3','1','system',' system','asuse_Sheet1_25_D_1_20260611131335098819')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','19','1','2411','system',' system','asuse_Sheet1_26_B_2411_20260611131335108814')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','19','2','0','system',' system','asuse_Sheet1_26_C_0_20260611131335117243')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','19','3','0','system',' system','asuse_Sheet1_26_D_0_20260611131335127321')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','20','1','8567','system',' system','asuse_Sheet1_27_B_8567_20260611131335139970')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','20','2','30','system',' system','asuse_Sheet1_27_C_30_20260611131335149654')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','20','3','42','system',' system','asuse_Sheet1_27_D_42_20260611131335159763')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','21','1','8835','system',' system','asuse_Sheet1_28_B_8835_20260611131335168558')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','21','2','162','system',' system','asuse_Sheet1_28_C_162_20260611131335177726')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','21','3','421','system',' system','asuse_Sheet1_28_D_421_20260611131335188213')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','22','1','19408','system',' system','asuse_Sheet1_29_B_19408_20260611131335195713')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','22','2','410','system',' system','asuse_Sheet1_29_C_410_20260611131335206474')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','22','3','1173','system',' system','asuse_Sheet1_29_D_1173_20260611131335216735')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','23','1','1395','system',' system','asuse_Sheet1_30_B_1395_20260611131335227444')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','23','2','0','system',' system','asuse_Sheet1_30_C_0_20260611131335238372')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','23','3','0','system',' system','asuse_Sheet1_30_D_0_20260611131335248337')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','24','1','15550','system',' system','asuse_Sheet1_31_B_15550_20260611131335258756')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','24','2','70','system',' system','asuse_Sheet1_31_C_70_20260611131335268471')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','24','3','231','system',' system','asuse_Sheet1_31_D_231_20260611131335279570')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','25','1','11899','system',' system','asuse_Sheet1_32_B_11899_20260611131335290483')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','25','2','40','system',' system','asuse_Sheet1_32_C_40_20260611131335301239')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','25','3','71','system',' system','asuse_Sheet1_32_D_71_20260611131335311222')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','26','1','2139','system',' system','asuse_Sheet1_33_B_2139_20260611131335321672')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','26','2','8','system',' system','asuse_Sheet1_33_C_8_20260611131335331726')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','26','3','20','system',' system','asuse_Sheet1_33_D_20_20260611131335343524')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','27','1','27481','system',' system','asuse_Sheet1_34_B_27481_20260611131335353369')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','27','2','242','system',' system','asuse_Sheet1_34_C_242_20260611131335363362')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','27','3','510','system',' system','asuse_Sheet1_34_D_510_20260611131335372339')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','28','1','4183','system',' system','asuse_Sheet1_35_B_4183_20260611131335383563')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','28','2','47','system',' system','asuse_Sheet1_35_C_47_20260611131335391164')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','28','3','108','system',' system','asuse_Sheet1_35_D_108_20260611131335401137')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','29','1','12845','system',' system','asuse_Sheet1_36_B_12845_20260611131335411373')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','29','2','307','system',' system','asuse_Sheet1_36_C_307_20260611131335423419')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','29','3','268','system',' system','asuse_Sheet1_36_D_268_20260611131335433253')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','30','1','591','system',' system','asuse_Sheet1_37_B_591_20260611131335444157')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','30','2','0','system',' system','asuse_Sheet1_37_C_0_20260611131335453755')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','30','3','13','system',' system','asuse_Sheet1_37_D_13_20260611131335463780')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','31','1','0','system',' system','asuse_Sheet1_38_B_0_20260611131335474523')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','31','2','0','system',' system','asuse_Sheet1_38_C_0_20260611131335485295')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','31','3','0','system',' system','asuse_Sheet1_38_D_0_20260611131335494352')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','32','1','1155','system',' system','asuse_Sheet1_39_B_1155_20260611131335504018')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','32','2','5','system',' system','asuse_Sheet1_39_C_5_20260611131335511627')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','32','3','31','system',' system','asuse_Sheet1_39_D_31_20260611131335520624')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','33','1','6449','system',' system','asuse_Sheet1_40_B_6449_20260611131335530625')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','33','2','106','system',' system','asuse_Sheet1_40_C_106_20260611131335539956')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','33','3','72','system',' system','asuse_Sheet1_40_D_72_20260611131335549958')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','34','1','476','system',' system','asuse_Sheet1_41_B_476_20260611131335559985')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','34','2','5','system',' system','asuse_Sheet1_41_C_5_20260611131335571160')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','34','3','6','system',' system','asuse_Sheet1_41_D_6_20260611131335583466')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','35','1','330','system',' system','asuse_Sheet1_42_B_330_20260611131335593523')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','35','2','4','system',' system','asuse_Sheet1_42_C_4_20260611131335603758')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','35','3','1','system',' system','asuse_Sheet1_42_D_1_20260611131335612722')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','36','1','704','system',' system','asuse_Sheet1_43_B_704_20260611131335625084')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','36','2','0','system',' system','asuse_Sheet1_43_C_0_20260611131335636165')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,number_of_establishments_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','36','3','1','system',' system','asuse_Sheet1_43_D_1_20260611131335646184')
# Read Excel Sheet: Sheet1
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','1','8.84','system',' system','asuse_Sheet1_8_E_8.84_20260611131335688543')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','2','34.81','system',' system','asuse_Sheet1_8_F_34.81_20260611131335699502')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','3','42.54','system',' system','asuse_Sheet1_8_G_42.54_20260611131335710032')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','4','13.81','system',' system','asuse_Sheet1_8_H_13.81_20260611131335720057')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','1','5','100','system',' system','asuse_Sheet1_8_I_100_20260611131335730558')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','1','0','system',' system','asuse_Sheet1_9_E_0_20260611131335742088')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','2','0','system',' system','asuse_Sheet1_9_F_0_20260611131335751118')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','3','0','system',' system','asuse_Sheet1_9_G_0_20260611131335762450')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','4','100','system',' system','asuse_Sheet1_9_H_100_20260611131335769739')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','2','5','100','system',' system','asuse_Sheet1_9_I_100_20260611131335779441')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','1','8.33','system',' system','asuse_Sheet1_10_E_8.33_20260611131335790451')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','2','50','system',' system','asuse_Sheet1_10_F_50_20260611131335802471')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','3','16.67','system',' system','asuse_Sheet1_10_G_16.67_20260611131335810400')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','4','25','system',' system','asuse_Sheet1_10_H_25_20260611131335820134')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','3','5','100','system',' system','asuse_Sheet1_10_I_100_20260611131335827536')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','1','5.84','system',' system','asuse_Sheet1_11_E_5.84_20260611131335840114')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','2','25.55','system',' system','asuse_Sheet1_11_F_25.55_20260611131335849755')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','3','57.66','system',' system','asuse_Sheet1_11_G_57.66_20260611131335860115')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','4','10.95','system',' system','asuse_Sheet1_11_H_10.95_20260611131335870406')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','4','5','100','system',' system','asuse_Sheet1_11_I_100_20260611131335879553')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','1','8.29','system',' system','asuse_Sheet1_12_E_8.29_20260611131335891261')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','2','38.95','system',' system','asuse_Sheet1_12_F_38.95_20260611131335899324')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','3','40.06','system',' system','asuse_Sheet1_12_G_40.06_20260611131335911425')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','4','12.71','system',' system','asuse_Sheet1_12_H_12.71_20260611131335922330')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','5','5','100','system',' system','asuse_Sheet1_12_I_100_20260611131335933060')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','1','0','system',' system','asuse_Sheet1_13_E_0_20260611131335943137')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','2','10.71','system',' system','asuse_Sheet1_13_F_10.71_20260611131335953088')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','3','85.71','system',' system','asuse_Sheet1_13_G_85.71_20260611131335962636')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','4','3.57','system',' system','asuse_Sheet1_13_H_3.57_20260611131335972313')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','6','5','100','system',' system','asuse_Sheet1_13_I_100_20260611131335983312')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','1','18.18','system',' system','asuse_Sheet1_14_E_18.18_20260611131335993213')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','2','36.36','system',' system','asuse_Sheet1_14_F_36.36_20260611131336002296')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','3','36.36','system',' system','asuse_Sheet1_14_G_36.36_20260611131336011262')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','4','9.09','system',' system','asuse_Sheet1_14_H_9.09_20260611131336019986')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','7','5','100','system',' system','asuse_Sheet1_14_I_100_20260611131336027725')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','1','9.04','system',' system','asuse_Sheet1_15_E_9.04_20260611131336036305')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','2','29.8','system',' system','asuse_Sheet1_15_F_29.8_20260611131336044328')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','3','50.99','system',' system','asuse_Sheet1_15_G_50.99_20260611131336052326')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','4','10.17','system',' system','asuse_Sheet1_15_H_10.17_20260611131336061180')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','8','5','100','system',' system','asuse_Sheet1_15_I_100_20260611131336069927')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','1','2.78','system',' system','asuse_Sheet1_16_E_2.78_20260611131336078997')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','2','48.35','system',' system','asuse_Sheet1_16_F_48.35_20260611131336087630')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','3','42.78','system',' system','asuse_Sheet1_16_G_42.78_20260611131336096550')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','4','6.08','system',' system','asuse_Sheet1_16_H_6.08_20260611131336106210')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','9','5','100','system',' system','asuse_Sheet1_16_I_100_20260611131336114390')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','1','2.51','system',' system','asuse_Sheet1_17_E_2.51_20260611131336124250')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','2','53.35','system',' system','asuse_Sheet1_17_F_53.35_20260611131336134387')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','3','32.68','system',' system','asuse_Sheet1_17_G_32.68_20260611131336146138')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','4','11.45','system',' system','asuse_Sheet1_17_H_11.45_20260611131336156962')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','10','5','100','system',' system','asuse_Sheet1_17_I_100_20260611131336167960')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','1','2.72','system',' system','asuse_Sheet1_18_E_2.72_20260611131336178500')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','2','27.21','system',' system','asuse_Sheet1_18_F_27.21_20260611131336189259')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','3','55.1','system',' system','asuse_Sheet1_18_G_55.1_20260611131336200076')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','4','14.97','system',' system','asuse_Sheet1_18_H_14.97_20260611131336211263')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','11','5','100','system',' system','asuse_Sheet1_18_I_100_20260611131336222517')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','1','9.54','system',' system','asuse_Sheet1_19_E_9.54_20260611131336234752')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','2','30.79','system',' system','asuse_Sheet1_19_F_30.79_20260611131336245971')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','3','54.22','system',' system','asuse_Sheet1_19_G_54.22_20260611131336257523')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','4','5.45','system',' system','asuse_Sheet1_19_H_5.45_20260611131336268755')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','12','5','100','system',' system','asuse_Sheet1_19_I_100_20260611131336279327')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','1','17.3','system',' system','asuse_Sheet1_20_E_17.3_20260611131336290509')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','2','53.18','system',' system','asuse_Sheet1_20_F_53.18_20260611131336297837')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','3','17.56','system',' system','asuse_Sheet1_20_G_17.56_20260611131336306098')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','4','11.96','system',' system','asuse_Sheet1_20_H_11.96_20260611131336316333')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','13','5','100','system',' system','asuse_Sheet1_20_I_100_20260611131336326913')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','1','5.84','system',' system','asuse_Sheet1_21_E_5.84_20260611131336337199')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','2','46.75','system',' system','asuse_Sheet1_21_F_46.75_20260611131336348510')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','3','32.79','system',' system','asuse_Sheet1_21_G_32.79_20260611131336360316')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','4','14.61','system',' system','asuse_Sheet1_21_H_14.61_20260611131336370332')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','14','5','100','system',' system','asuse_Sheet1_21_I_100_20260611131336379299')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','1','15','1','6.55','system',' system','asuse_Sheet1_22_E_6.55_20260611131336391885')
# ...
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','26','1','11.3','system',' system','asuse_Sheet1_119_E_11.3_20260611131342801974')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','26','2','32.17','system',' system','asuse_Sheet1_119_F_32.17_20260611131342811972')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','26','3','35.65','system',' system','asuse_Sheet1_119_G_35.65_20260611131342822283')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','26','4','20.87','system',' system','asuse_Sheet1_119_H_20.87_20260611131342831398')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','26','5','100','system',' system','asuse_Sheet1_119_I_100_20260611131342842320')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','27','1','6.35','system',' system','asuse_Sheet1_120_E_6.35_20260611131342852028')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','27','2','50.27','system',' system','asuse_Sheet1_120_F_50.27_20260611131342862522')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','27','3','32.31','system',' system','asuse_Sheet1_120_G_32.31_20260611131342872918')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','27','4','11.07','system',' system','asuse_Sheet1_120_H_11.07_20260611131342880945')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','27','5','100','system',' system','asuse_Sheet1_120_I_100_20260611131342891426')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','28','1','6.74','system',' system','asuse_Sheet1_121_E_6.74_20260611131342900463')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','28','2','33.72','system',' system','asuse_Sheet1_121_F_33.72_20260611131342910628')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','28','3','42.79','system',' system','asuse_Sheet1_121_G_42.79_20260611131342922511')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','28','4','16.74','system',' system','asuse_Sheet1_121_H_16.74_20260611131342932727')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','28','5','100','system',' system','asuse_Sheet1_121_I_100_20260611131342943283')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','29','1','5.27','system',' system','asuse_Sheet1_122_E_5.27_20260611131342953318')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','29','2','40.66','system',' system','asuse_Sheet1_122_F_40.66_20260611131342963331')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','29','3','40.48','system',' system','asuse_Sheet1_122_G_40.48_20260611131342971947')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','29','4','13.6','system',' system','asuse_Sheet1_122_H_13.6_20260611131342982947')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','29','5','100','system',' system','asuse_Sheet1_122_I_100_20260611131342992180')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','30','1','3.7','system',' system','asuse_Sheet1_123_E_3.7_20260611131343003203')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','30','2','44.44','system',' system','asuse_Sheet1_123_F_44.44_20260611131343014154')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','30','3','33.33','system',' system','asuse_Sheet1_123_G_33.33_20260611131343024247')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','30','4','18.52','system',' system','asuse_Sheet1_123_H_18.52_20260611131343033889')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','30','5','100','system',' system','asuse_Sheet1_123_I_100_20260611131343041017')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','31','1','23.08','system',' system','asuse_Sheet1_124_E_23.08_20260611131343051099')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','31','2','8.97','system',' system','asuse_Sheet1_124_F_8.97_20260611131343061084')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','31','3','61.54','system',' system','asuse_Sheet1_124_G_61.54_20260611131343071863')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','31','4','6.41','system',' system','asuse_Sheet1_124_H_6.41_20260611131343081937')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','31','5','100','system',' system','asuse_Sheet1_124_I_100_20260611131343091884')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','32','1','5.56','system',' system','asuse_Sheet1_125_E_5.56_20260611131343103418')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','32','2','25','system',' system','asuse_Sheet1_125_F_25_20260611131343112525')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','32','3','52.78','system',' system','asuse_Sheet1_125_G_52.78_20260611131343122967')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','32','4','16.67','system',' system','asuse_Sheet1_125_H_16.67_20260611131343132787')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','32','5','100','system',' system','asuse_Sheet1_125_I_100_20260611131343144922')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','33','1','5.79','system',' system','asuse_Sheet1_126_E_5.79_20260611131343153277')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','33','2','58.49','system',' system','asuse_Sheet1_126_F_58.49_20260611131343163523')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','33','3','26.64','system',' system','asuse_Sheet1_126_G_26.64_20260611131343173743')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','33','4','9.07','system',' system','asuse_Sheet1_126_H_9.07_20260611131343185152')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','33','5','100','system',' system','asuse_Sheet1_126_I_100_20260611131343195897')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','34','1','10.26','system',' system','asuse_Sheet1_127_E_10.26_20260611131343208348')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','34','2','66.67','system',' system','asuse_Sheet1_127_F_66.67_20260611131343218368')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','34','3','17.95','system',' system','asuse_Sheet1_127_G_17.95_20260611131343229039')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','34','4','5.13','system',' system','asuse_Sheet1_127_H_5.13_20260611131343239070')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','34','5','100','system',' system','asuse_Sheet1_127_I_100_20260611131343249469')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','35','1','14.29','system',' system','asuse_Sheet1_128_E_14.29_20260611131343259879')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','35','2','42.86','system',' system','asuse_Sheet1_128_F_42.86_20260611131343271206')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','35','3','35.71','system',' system','asuse_Sheet1_128_G_35.71_20260611131343281417')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','35','4','7.14','system',' system','asuse_Sheet1_128_H_7.14_20260611131343291720')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','35','5','100','system',' system','asuse_Sheet1_128_I_100_20260611131343302942')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','36','1','23.08','system',' system','asuse_Sheet1_129_E_23.08_20260611131343314699')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','36','2','38.46','system',' system','asuse_Sheet1_129_F_38.46_20260611131343324793')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','36','3','12.82','system',' system','asuse_Sheet1_129_G_12.82_20260611131343334905')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','36','4','25.64','system',' system','asuse_Sheet1_129_H_25.64_20260611131343345291')
# insert into asuse_fact_new_table_2(indicator_code,sector_code,state_code,percentage_distribution_for_original_sample_not_surveyed_code,indicator_value,created_by,updated_by,asuse_fact_code) values('52','3','36','5','100','system',' system','asuse_Sheet1_129_I_100_20260611131343353325')
# Data insert successfully
