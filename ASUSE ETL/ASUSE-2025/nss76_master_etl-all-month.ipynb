# %%
import pandas as pd
import configparser as cp
import psycopg2
from openpyxl.utils import column_index_from_string
from openpyxl.utils import get_column_letter

# %%
config = cp.RawConfigParser()
config_files = ['Table-21.properties']


print(config_files)
# Out:
# ['Table-20.properties']

# %%
#read property file

for file in config_files:
    print('Currently Read File  :- ' + file)
    config.read(file)
    #config.read(file, encoding='utf-8-sig')

    
    ip = config.get('database_details', 'database.ip')
    port = config.get('database_details', 'database.port')
    username = config.get('database_details', 'database.username')
    password = config.get('database_details', 'database.password')
    dbname = config.get('database_details', 'database.dbname')
    tablename = config.get('database_details', 'database.tablename')


    
    connection = psycopg2.connect(database=dbname, user=username, password=password, host=ip, port=port)
    cursor = connection.cursor()
    
    sheet_location = config.get('master_properties', 'sheet_path')
    print('reading excel file:',sheet_location)
    
    
    
    #read property env.tables.unique.sheets and start the nested loops
    unique_sheet_count = int(config.get('tables_for_etl', 'etl.tables.unique.sheets'))
    
    #below loop for unique sheets only
    for i in range(unique_sheet_count):
        print('Starting for i(Unique Sheets Count):',i)
        #run below loop for blocks that are split across sheets for "each" unique sheet
        block_count = int(config.get('tables_for_etl', 'etl.tables.table.'+str(i+1)+'.block.count'))
       
    
        
        for j in range(block_count):
            # skipCellAfter =  int(config.get('tables_for_etl', 'etl.tables.table.'+str(i+1)+'.block.skipCellAfter'))
            # skipNoOfCell =  int(config.get('tables_for_etl', 'etl.tables.table.'+str(i+1)+'.block.skipNoOfCell'))
            header_names = config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.header.names').split(',')
            row_seggregation_level = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.rows.seggregation.level.count'))
            col_seggregation_level = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.level.count'))
            row_start = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.row.start'))
            row_end = int(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.row.end'))
            col_start = column_index_from_string(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.col.start'))
            col_end = column_index_from_string(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.col.end'))
        
            row_seggregation_foreign_list = []
            row_seggregation_foreignValue_list = []

            col_seggregation_foreign_list = []
            col_seggregation_loopValue_list = []
            col_seggregation_repeteAfter_list = []
            col_seggregation_foreignValue_list = []
            
            for k in range(int(row_seggregation_level)):
                row_seggregation_foreign_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.rows.seggregation.'+str(k+1)+'.foreign'))
                row_seggregation_foreignValue_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.rows.seggregation.'+str(k+1)+'.foreignValue'))
            
            
            for l in range(int(col_seggregation_level)):
                col_seggregation_foreign_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.foreign'))
                col_seggregation_loopValue_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.loopValue'))
                col_seggregation_repeteAfter_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.totalRows'))
                col_seggregation_foreignValue_list.append(config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.cols.seggregation.'+str(l+1)+'.foreignValue'))





            header_values = config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.sheet.header.values').split(',')
            sheet_name = config.get('tables_for_etl', 'etl.tables.table.'+str(j+1)+'.block.'+str(j+1)+'.sheet')
            input_df = pd.read_excel(sheet_location,sheet_name)

            print('Read Excel Sheet:',sheet_name)
            for row in range(row_start-2,row_end-1):
                for col in range(col_start-1,col_end):

                    base = (row + 2) - row_start

                    # if base == 0 or not (base >= 16 and (base - 16) % 18 in (0, 1)):
                        

                    insert_query_prefix = "insert into " + tablename + "("+""
                    insert_query_suffix = " values("+"'"

                    
                    for o in range(len(header_names)):
                        insert_query_prefix = insert_query_prefix + header_names[o] +","
                        insert_query_suffix = insert_query_suffix + header_values[o]+"','"

                    col_seggregation_foreignValue_list = [
                        x.split(",") if isinstance(x, str) else x
                        for x in col_seggregation_foreignValue_list
                    ]


                    row_seggregation_foreignValue_list = [
                        x.split(",") if isinstance(x, str) else x
                        for x in row_seggregation_foreignValue_list
                    ]

                    
                    for m in range(len(col_seggregation_foreign_list)):

                        insert_query_prefix += col_seggregation_foreign_list[m] + ","

                        repeat = int(col_seggregation_repeteAfter_list[m])
                        loop = int(col_seggregation_loopValue_list[m])
                        

                        # if m == 0:
                        #     new_val = base // repeat

                        # elif m == 1:
                        #     new_val_1 = (base // repeat)
                        #     new_val =  (base //  int(col_seggregation_loopValue_list[m])) - ((int(col_seggregation_repeteAfter_list[m])//int(col_seggregation_loopValue_list[m])) * new_val_1)
                            
                        # elif m == 2:
                        #     new_val_1 = (base // repeat)
                        #     new_val =  (base //  int(col_seggregation_loopValue_list[m])) - ((int(col_seggregation_repeteAfter_list[m])//int(col_seggregation_loopValue_list[m])) * new_val_1)

                        if m == 0:
                            new_val = base % loop

                        
                        values_list = col_seggregation_foreignValue_list[m]

                        if new_val < len(values_list):
                            insert_query_suffix += values_list[new_val] + "','"
                        else:
                            insert_query_suffix += "NULL','"   # safety
                    
                                    
                    
                    indicator_val = input_df.iloc[row].values[col]

                    if indicator_val == 'x':
                        print('skipping, indicator_val['+str(row+2)+']['+str(get_column_letter(col+1))+']:',indicator_val)

                    for m in range(len(row_seggregation_foreign_list)):
                        insert_query_prefix += row_seggregation_foreign_list[m] + ","
                        values = row_seggregation_foreignValue_list[m][col - (col_start-1)]
                        insert_query_suffix += values + "','"

                        # month_code = row_seggregation_foreignValue_list[0][col - 4]
                
                    # print('Inserting, indicator_val['+str(row+2)+']['+str(get_column_letter(col+1))+']:',indicator_val)
    
    
                    insert_query_prefix = insert_query_prefix  +"indicator_value,"
                    insert_query_suffix = insert_query_suffix + str(indicator_val)+"','"

                    # insert_query_prefix = insert_query_prefix  +"month_code,"
                    # insert_query_suffix = insert_query_suffix + month_code+"','"
    
                    insert_query_prefix = insert_query_prefix  +"created_by,"
                    insert_query_suffix = insert_query_suffix + 'system' +"','"
                    insert_query_prefix = insert_query_prefix  +"updated_by,"
                    insert_query_suffix = insert_query_suffix + ' system' +"','"
    
                    from datetime import datetime

                    # insert_query_prefix = insert_query_prefix  +"year,"
                    # insert_query_suffix = insert_query_suffix + sheet_year +"','"
                    timestamp = datetime.now().strftime("%Y%m%d%H%M%S%f")
    
                    fact_code = f"asuse_{sheet_name}_{row+2}_{get_column_letter(col+1)}_{indicator_val}_{timestamp}"
                    # nfhs_fact_code = f"nss76_{sheet_name}_{row+2}_{get_column_letter(col+1)}_{indicator_val}"
                    fact_code = fact_code.replace(' ', '')
                    insert_query_prefix = insert_query_prefix + "asuse_fact_code)"
                    insert_query_suffix = insert_query_suffix + fact_code+"')"
    
                    final_query = insert_query_prefix+insert_query_suffix
                    print(final_query)
                    cursor.execute(final_query)
                    
                    connection.commit()


connection.close()
print('Data insert successfully')
# Out:
# Currently Read File  :- Table-20.properties
# reading excel file: D:\Tables - ASUSE 2025\Table-20.xlsx
# Starting for i(Unique Sheets Count): 0
# Read Excel Sheet: Sheet1
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','1','1','system',' system','asuse_Sheet1_6_B_1_20260617144755663372')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','2','68','system',' system','asuse_Sheet1_6_C_68_20260617144755679274')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','3','5','system',' system','asuse_Sheet1_6_D_5_20260617144755687523')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','1','173','system',' system','asuse_Sheet1_6_E_173_20260617144755696260')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','2','573','system',' system','asuse_Sheet1_6_F_573_20260617144755704250')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','3','196','system',' system','asuse_Sheet1_6_G_196_20260617144755710413')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','1','12237438','system',' system','asuse_Sheet1_6_H_12237438_20260617144755716350')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','2','728391','system',' system','asuse_Sheet1_6_I_728391_20260617144755723025')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','3','12965829','system',' system','asuse_Sheet1_6_J_12965829_20260617144755729187')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','1','11','system',' system','asuse_Sheet1_7_B_11_20260617144755735157')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','2','221','system',' system','asuse_Sheet1_7_C_221_20260617144755741122')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','3','26','system',' system','asuse_Sheet1_7_D_26_20260617144755747288')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','1','401','system',' system','asuse_Sheet1_7_E_401_20260617144755753144')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','2','743','system',' system','asuse_Sheet1_7_F_743_20260617144755759036')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','3','427','system',' system','asuse_Sheet1_7_G_427_20260617144755764090')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','1','11116924','system',' system','asuse_Sheet1_7_H_11116924_20260617144755770096')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','2','906701','system',' system','asuse_Sheet1_7_I_906701_20260617144755776023')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','3','12023625','system',' system','asuse_Sheet1_7_J_12023625_20260617144755781247')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','1','38','system',' system','asuse_Sheet1_8_B_38_20260617144755791277')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','2','196','system',' system','asuse_Sheet1_8_C_196_20260617144755801408')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','3','51','system',' system','asuse_Sheet1_8_D_51_20260617144755810517')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','1','293','system',' system','asuse_Sheet1_8_E_293_20260617144755821431')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','2','579','system',' system','asuse_Sheet1_8_F_579_20260617144755831532')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','3','316','system',' system','asuse_Sheet1_8_G_316_20260617144755841459')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','1','16010074','system',' system','asuse_Sheet1_8_H_16010074_20260617144755850815')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','2','1413149','system',' system','asuse_Sheet1_8_I_1413149_20260617144755859927')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','3','17423223','system',' system','asuse_Sheet1_8_J_17423223_20260617144755869454')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','1','19','system',' system','asuse_Sheet1_9_B_19_20260617144755880407')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','2','173','system',' system','asuse_Sheet1_9_C_173_20260617144755891423')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','3','30','system',' system','asuse_Sheet1_9_D_30_20260617144755900399')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','1','286','system',' system','asuse_Sheet1_9_E_286_20260617144755909374')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','2','626','system',' system','asuse_Sheet1_9_F_626_20260617144755919413')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','3','311','system',' system','asuse_Sheet1_9_G_311_20260617144755928558')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','1','39365517','system',' system','asuse_Sheet1_9_H_39365517_20260617144755935670')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','2','3048371','system',' system','asuse_Sheet1_9_I_3048371_20260617144755944585')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','3','42413889','system',' system','asuse_Sheet1_9_J_42413889_20260617144755951579')
# Read Excel Sheet: Sheet1
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','1','7','system',' system','asuse_Sheet1_25_B_7_20260617144756065456')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','2','129','system',' system','asuse_Sheet1_25_C_129_20260617144756082348')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','3','31','system',' system','asuse_Sheet1_25_D_31_20260617144756093092')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','1','272','system',' system','asuse_Sheet1_25_E_272_20260617144756104118')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','2','695','system',' system','asuse_Sheet1_25_F_695_20260617144756112132')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','3','353','system',' system','asuse_Sheet1_25_G_353_20260617144756121211')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','1','6855696','system',' system','asuse_Sheet1_25_H_6855696_20260617144756132276')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','2','1629763','system',' system','asuse_Sheet1_25_I_1629763_20260617144756141583')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','3','8485459','system',' system','asuse_Sheet1_25_J_8485459_20260617144756151256')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','1','27','system',' system','asuse_Sheet1_26_B_27_20260617144756159441')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','2','251','system',' system','asuse_Sheet1_26_C_251_20260617144756169981')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','3','84','system',' system','asuse_Sheet1_26_D_84_20260617144756180183')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','1','542','system',' system','asuse_Sheet1_26_E_542_20260617144756190261')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','2','782','system',' system','asuse_Sheet1_26_F_782_20260617144756198369')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','3','603','system',' system','asuse_Sheet1_26_G_603_20260617144756206356')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','1','9109898','system',' system','asuse_Sheet1_26_H_9109898_20260617144756217335')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','2','3081991','system',' system','asuse_Sheet1_26_I_3081991_20260617144756227290')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','3','12191889','system',' system','asuse_Sheet1_26_J_12191889_20260617144756235868')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','1','62','system',' system','asuse_Sheet1_27_B_62_20260617144756243235')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','2','360','system',' system','asuse_Sheet1_27_C_360_20260617144756254207')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','3','114','system',' system','asuse_Sheet1_27_D_114_20260617144756262433')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','1','408','system',' system','asuse_Sheet1_27_E_408_20260617144756270184')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','2','794','system',' system','asuse_Sheet1_27_F_794_20260617144756279815')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','3','475','system',' system','asuse_Sheet1_27_G_475_20260617144756288835')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','1','13329598','system',' system','asuse_Sheet1_27_H_13329598_20260617144756298283')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','2','2825281','system',' system','asuse_Sheet1_27_I_2825281_20260617144756307849')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','3','16154879','system',' system','asuse_Sheet1_27_J_16154879_20260617144756319147')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','1','39','system',' system','asuse_Sheet1_28_B_39_20260617144756328382')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','2','266','system',' system','asuse_Sheet1_28_C_266_20260617144756337252')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','3','85','system',' system','asuse_Sheet1_28_D_85_20260617144756346407')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','1','418','system',' system','asuse_Sheet1_28_E_418_20260617144756355962')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','2','768','system',' system','asuse_Sheet1_28_F_768_20260617144756366283')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','3','489','system',' system','asuse_Sheet1_28_G_489_20260617144756375958')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','1','29295381','system',' system','asuse_Sheet1_28_H_29295381_20260617144756385319')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','2','7537275','system',' system','asuse_Sheet1_28_I_7537275_20260617144756395218')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','3','36832656','system',' system','asuse_Sheet1_28_J_36832656_20260617144756403037')
# Read Excel Sheet: Sheet1
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','1','3','system',' system','asuse_Sheet1_44_B_3_20260617144756500540')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','2','110','system',' system','asuse_Sheet1_44_C_110_20260617144756509935')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','1','3','15','system',' system','asuse_Sheet1_44_D_15_20260617144756520081')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','1','209','system',' system','asuse_Sheet1_44_E_209_20260617144756528811')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','2','657','system',' system','asuse_Sheet1_44_F_657_20260617144756537124')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','2','3','258','system',' system','asuse_Sheet1_44_G_258_20260617144756548030')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','1','19093134','system',' system','asuse_Sheet1_44_H_19093134_20260617144756556866')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','2','2358154','system',' system','asuse_Sheet1_44_I_2358154_20260617144756568129')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','1','3','3','21451288','system',' system','asuse_Sheet1_44_J_21451288_20260617144756577237')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','1','18','system',' system','asuse_Sheet1_45_B_18_20260617144756587181')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','2','244','system',' system','asuse_Sheet1_45_C_244_20260617144756595180')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','1','3','55','system',' system','asuse_Sheet1_45_D_55_20260617144756605948')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','1','465','system',' system','asuse_Sheet1_45_E_465_20260617144756616037')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','2','773','system',' system','asuse_Sheet1_45_F_773_20260617144756626109')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','2','3','516','system',' system','asuse_Sheet1_45_G_516_20260617144756635946')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','1','20226821','system',' system','asuse_Sheet1_45_H_20226821_20260617144756647202')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','2','3988692','system',' system','asuse_Sheet1_45_I_3988692_20260617144756657659')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','2','3','3','24215514','system',' system','asuse_Sheet1_45_J_24215514_20260617144756667909')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','1','49','system',' system','asuse_Sheet1_46_B_49_20260617144756678529')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','2','305','system',' system','asuse_Sheet1_46_C_305_20260617144756689378')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','1','3','82','system',' system','asuse_Sheet1_46_D_82_20260617144756700306')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','1','345','system',' system','asuse_Sheet1_46_E_345_20260617144756708243')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','2','722','system',' system','asuse_Sheet1_46_F_722_20260617144756719309')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','2','3','392','system',' system','asuse_Sheet1_46_G_392_20260617144756730925')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','1','29339671','system',' system','asuse_Sheet1_46_H_29339671_20260617144756741114')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','2','4238430','system',' system','asuse_Sheet1_46_I_4238430_20260617144756751178')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','3','3','3','33578102','system',' system','asuse_Sheet1_46_J_33578102_20260617144756758697')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','1','27','system',' system','asuse_Sheet1_47_B_27_20260617144756768194')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','2','239','system',' system','asuse_Sheet1_47_C_239_20260617144756775067')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','1','3','56','system',' system','asuse_Sheet1_47_D_56_20260617144756783577')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','1','342','system',' system','asuse_Sheet1_47_E_342_20260617144756792140')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','2','727','system',' system','asuse_Sheet1_47_F_727_20260617144756802115')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','2','3','394','system',' system','asuse_Sheet1_47_G_394_20260617144756809613')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','1','68660898','system',' system','asuse_Sheet1_47_H_68660898_20260617144756819693')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','2','10585647','system',' system','asuse_Sheet1_47_I_10585647_20260617144756830205')
# insert into asuse_fact_new_table_20(indicator_code,sector_code,bac_code,numbers_by_internet_and_computer_usage,establishment_type_code,indicator_value,created_by,updated_by,asuse_fact_code) values('20','1','4','3','3','79246545','system',' system','asuse_Sheet1_47_J_79246545_20260617144756840871')
# Data insert successfully
