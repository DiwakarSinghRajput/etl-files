# %%
import pandas as pd
import configparser as cp
import psycopg2
from openpyxl.utils import column_index_from_string
from openpyxl.utils import get_column_letter

# %%
config = cp.RawConfigParser()
config_files = ['plfs_monthly.properties']


print(config_files)
# Out:
# ['plfs_monthly.properties']

# %%
#read property file

for file in config_files:
    print('Currently Read File  :- ' + file)
    config.read(file)
    
    filename=file.split('.')[0]
    ip = config.get('database_details', 'database.ip')
    port = config.get('database_details', 'database.port')
    username = config.get('database_details', 'database.username')
    password = config.get('database_details', 'database.password')
    dbname = config.get('database_details', 'database.dbname')


    
    connection = psycopg2.connect(database=dbname, user=username, password=password, host=ip, port=port)
    cursor = connection.cursor()
    
    sheet_location = config.get('master_properties', 'sheet_path')
    print('reading excel file:',sheet_location)
    
    
    
    #read property plfs.tables.unique.sheets and start the nested loops
    unique_sheet_count = int(config.get('plfs_tables_for_etl', 'plfs.tables.unique.sheets'))
    
    #below loop for unique sheets only
    for i in range(unique_sheet_count):
        print('Starting for i(Unique Sheets Count):',i)
        #run below loop for blocks that are split across sheets for "each" unique sheet
        block_count = int(config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.block.count'))
        header_names = config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.header.names').split(',')
        row_seggregation_level = int(config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.rows.seggregation.level.count'))
        col_seggregation_level = int(config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.cols.seggregation.level.count'))
        row_start = int(config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.row.start'))
        row_end = int(config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.row.end'))
        col_start = column_index_from_string(config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.col.start'))
        col_end = column_index_from_string(config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.col.end'))
    
        row_seggregation_values_list = []
        row_seggregation_criteria_list = []
        col_seggregation_values_list = []
        col_seggregation_criteria_list = []
        for k in range(int(row_seggregation_level)):
            row_seggregation_values_list.append(((config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.rows.seggregation.'+str(k+1)+'.values')).split(',')))
            row_seggregation_criteria_list.append(((config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.rows.seggregation.'+str(k+1)+'.criteria'))))
        for l in range(int(col_seggregation_level)):
            col_seggregation_values_list.append(((config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.cols.seggregation.'+str(l+1)+'.values')).split(',')))
            col_seggregation_criteria_list.append(((config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.cols.seggregation.'+str(l+1)+'.criteria'))))
    
        #print('row_seggregation_criteria_list:',row_seggregation_criteria_list)
        #print('row_seggregation_values_list:',row_seggregation_values_list)
        
        #print('col_seggregation_criteria_list:',col_seggregation_criteria_list)
        #print('col_seggregation_values_list:',col_seggregation_values_list)
    
        
        for j in range(block_count):
            header_values = config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.block.'+str(j+1)+'.sheet.header.values').split(',')
            sheet_name = config.get('plfs_tables_for_etl', 'plfs.tables.table.'+str(i+1)+'.block.'+str(j+1)+'.sheet')
            input_df = pd.read_excel(sheet_location,sheet_name)
            print('Read Excel Sheet:',sheet_name)
            for row in range(row_start-2,row_end-1):
                for col in range(col_start-1,col_end):
                    insert_query_prefix = "insert into plfs_fact("+""
                    insert_query_suffix = " values("+"'"
                    for m in range(len(row_seggregation_criteria_list)):
                        if row_seggregation_values_list[m][(row+2)-row_start] == 'NULL' :
                             continue  
                        insert_query_prefix = insert_query_prefix + row_seggregation_criteria_list[m] +","
                        insert_query_suffix = insert_query_suffix + row_seggregation_values_list[m][(row+2)-row_start] +"','"
                    for n in range(len(col_seggregation_criteria_list)):
                        if col_seggregation_values_list[n][col-col_start+1] == 'NULL' :
                             continue
                        insert_query_prefix = insert_query_prefix + col_seggregation_criteria_list[n] +","
                        insert_query_suffix = insert_query_suffix + col_seggregation_values_list[n][col-col_start+1]+"','"
                        #print('col_seggregation_criteria_list['+str(n)+']:',col_seggregation_criteria_list[n],' col_seggregation_values_list['+str(n)+']['+str(col-col_start+1)+']:',col_seggregation_values_list[n][col-col_start])
                    
                    
                    indicator_val = input_df.iloc[row].values[col]
                   
                    # print('Inserting, indicator_val['+str(row+2)+']['+str(get_column_letter(col+1))+']:',indicator_val)
    
                    for o in range(len(header_names)):
                        insert_query_prefix = insert_query_prefix + header_names[o] +","
                        insert_query_suffix = insert_query_suffix + header_values[o]+"','"
    
                    insert_query_prefix = insert_query_prefix  +"indicator_value,"
                    # rounded_number = round(float(indicator_val), 2)
                    insert_query_suffix = insert_query_suffix + str(indicator_val)+"','"
    
                    insert_query_prefix = insert_query_prefix  +"created_by,"
                    insert_query_suffix = insert_query_suffix + 'system' +"','"
                    insert_query_prefix = insert_query_prefix  +"updated_by,"
                    insert_query_suffix = insert_query_suffix + ' system' +"','"
    
                    
                    # insert_query_prefix = insert_query_prefix  +"year,"
                    # insert_query_suffix = insert_query_suffix + sheet_year +"','"
    
    
                    plfs_fact_code = filename+'plfs_'+'_'+sheet_name+'_'+str(row+2)+'_'+str(get_column_letter(col+1))+'_'+ str(indicator_val)
                    plfs_fact_code = plfs_fact_code.replace(' ', '')
                    insert_query_prefix = insert_query_prefix + "plfs_fact_code)"
                    insert_query_suffix = insert_query_suffix + plfs_fact_code+"')"
    
                    final_query = insert_query_prefix+insert_query_suffix
                    print(final_query)
                    cursor.execute(final_query)
                     
                    connection.commit()

connection.close()
print('Data insert successfully')
# Out:
# Currently Read File  :- plfs_monthly.properties
# reading excel file: D:\Others\diwakar\etl-files\plfs\monthly\PLFS\Data\PLFS Monthly data May-2026.xlsx
# Starting for i(Unique Sheets Count): 0
# Read Excel Sheet: LFPR
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','1','1','3','2026','60.8','system',' system','plfs_monthlyplfs__LFPR_111_D_60.8')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','2','1','3','2026','22.4','system',' system','plfs_monthlyplfs__LFPR_111_E_22.4')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','3','1','3','2026','41.3','system',' system','plfs_monthlyplfs__LFPR_111_F_41.3')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','1','1','3','2026','78.1','system',' system','plfs_monthlyplfs__LFPR_112_D_78.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','2','1','3','2026','38.2','system',' system','plfs_monthlyplfs__LFPR_112_E_38.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','3','1','3','2026','57.5','system',' system','plfs_monthlyplfs__LFPR_112_F_57.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','1','1','3','2026','56.9','system',' system','plfs_monthlyplfs__LFPR_113_D_56.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','2','1','3','2026','28.8','system',' system','plfs_monthlyplfs__LFPR_113_E_28.8')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','3','1','3','2026','42.6','system',' system','plfs_monthlyplfs__LFPR_113_F_42.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','1','1','3','2026','59.6','system',' system','plfs_monthlyplfs__LFPR_114_D_59.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','2','1','3','2026','20.7','system',' system','plfs_monthlyplfs__LFPR_114_E_20.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','3','1','3','2026','40.9','system',' system','plfs_monthlyplfs__LFPR_114_F_40.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','1','1','3','2026','75.2','system',' system','plfs_monthlyplfs__LFPR_115_D_75.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','2','1','3','2026','25','system',' system','plfs_monthlyplfs__LFPR_115_E_25')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','3','1','3','2026','50.1','system',' system','plfs_monthlyplfs__LFPR_115_F_50.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','1','1','3','2026','58.7','system',' system','plfs_monthlyplfs__LFPR_116_D_58.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','2','1','3','2026','20','system',' system','plfs_monthlyplfs__LFPR_116_E_20')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','3','1','3','2026','39.5','system',' system','plfs_monthlyplfs__LFPR_116_F_39.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','1','1','3','2026','60.4','system',' system','plfs_monthlyplfs__LFPR_117_D_60.4')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','2','1','3','2026','21.9','system',' system','plfs_monthlyplfs__LFPR_117_E_21.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','3','1','3','2026','41.2','system',' system','plfs_monthlyplfs__LFPR_117_F_41.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','1','1','3','2026','77.1','system',' system','plfs_monthlyplfs__LFPR_118_D_77.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','2','1','3','2026','33.9','system',' system','plfs_monthlyplfs__LFPR_118_E_33.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','3','1','3','2026','55','system',' system','plfs_monthlyplfs__LFPR_118_F_55')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','1','1','3','2026','57.5','system',' system','plfs_monthlyplfs__LFPR_119_D_57.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','2','1','3','2026','26','system',' system','plfs_monthlyplfs__LFPR_119_E_26')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','3','1','3','2026','41.6','system',' system','plfs_monthlyplfs__LFPR_119_F_41.6')
# Starting for i(Unique Sheets Count): 1
# Read Excel Sheet: WPR
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','1','2','3','2026','52.7','system',' system','plfs_monthlyplfs__WPR_111_D_52.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','2','2','3','2026','18.8','system',' system','plfs_monthlyplfs__WPR_111_E_18.8')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','3','2','3','2026','35.5','system',' system','plfs_monthlyplfs__WPR_111_F_35.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','1','2','3','2026','74.5','system',' system','plfs_monthlyplfs__WPR_112_D_74.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','2','2','3','2026','36.5','system',' system','plfs_monthlyplfs__WPR_112_E_36.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','3','2','3','2026','54.9','system',' system','plfs_monthlyplfs__WPR_112_F_54.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','1','2','3','2026','54.2','system',' system','plfs_monthlyplfs__WPR_113_D_54.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','2','2','3','2026','27.5','system',' system','plfs_monthlyplfs__WPR_113_E_27.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','3','2','3','2026','40.7','system',' system','plfs_monthlyplfs__WPR_113_F_40.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','1','2','3','2026','50.1','system',' system','plfs_monthlyplfs__WPR_114_D_50.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','2','2','3','2026','15.6','system',' system','plfs_monthlyplfs__WPR_114_E_15.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','3','2','3','2026','33.5','system',' system','plfs_monthlyplfs__WPR_114_F_33.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','1','2','3','2026','70.7','system',' system','plfs_monthlyplfs__WPR_115_D_70.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','2','2','3','2026','22.9','system',' system','plfs_monthlyplfs__WPR_115_E_22.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','3','2','3','2026','46.8','system',' system','plfs_monthlyplfs__WPR_115_F_46.8')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','1','2','3','2026','55.2','system',' system','plfs_monthlyplfs__WPR_116_D_55.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','2','2','3','2026','18.3','system',' system','plfs_monthlyplfs__WPR_116_E_18.3')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','3','2','3','2026','36.9','system',' system','plfs_monthlyplfs__WPR_116_F_36.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','1','2','3','2026','51.8','system',' system','plfs_monthlyplfs__WPR_117_D_51.8')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','2','2','3','2026','17.8','system',' system','plfs_monthlyplfs__WPR_117_E_17.8')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','3','2','3','2026','34.9','system',' system','plfs_monthlyplfs__WPR_117_F_34.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','1','2','3','2026','73.2','system',' system','plfs_monthlyplfs__WPR_118_D_73.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','2','2','3','2026','32.1','system',' system','plfs_monthlyplfs__WPR_118_E_32.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','3','2','3','2026','52.2','system',' system','plfs_monthlyplfs__WPR_118_F_52.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','1','2','3','2026','54.5','system',' system','plfs_monthlyplfs__WPR_119_D_54.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','2','2','3','2026','24.6','system',' system','plfs_monthlyplfs__WPR_119_E_24.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','3','2','3','2026','39.5','system',' system','plfs_monthlyplfs__WPR_119_F_39.5')
# Starting for i(Unique Sheets Count): 2
# Read Excel Sheet: UR
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','1','3','3','2026','13.3','system',' system','plfs_monthlyplfs__UR_111_D_13.3')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','2','3','3','2026','16.2','system',' system','plfs_monthlyplfs__UR_111_E_16.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','1','3','3','3','2026','14.1','system',' system','plfs_monthlyplfs__UR_111_F_14.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','1','3','3','2026','4.7','system',' system','plfs_monthlyplfs__UR_112_D_4.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','2','3','3','2026','4.4','system',' system','plfs_monthlyplfs__UR_112_E_4.4')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','1','3','3','3','2026','4.6','system',' system','plfs_monthlyplfs__UR_112_F_4.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','1','3','3','2026','4.7','system',' system','plfs_monthlyplfs__UR_113_D_4.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','2','3','3','2026','4.4','system',' system','plfs_monthlyplfs__UR_113_E_4.4')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','1','3','3','3','2026','4.6','system',' system','plfs_monthlyplfs__UR_113_F_4.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','1','3','3','2026','15.9','system',' system','plfs_monthlyplfs__UR_114_D_15.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','2','3','3','2026','24.5','system',' system','plfs_monthlyplfs__UR_114_E_24.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','2','3','3','3','2026','18','system',' system','plfs_monthlyplfs__UR_114_F_18')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','1','3','3','2026','5.9','system',' system','plfs_monthlyplfs__UR_115_D_5.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','2','3','3','2026','8.5','system',' system','plfs_monthlyplfs__UR_115_E_8.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','2','3','3','3','2026','6.6','system',' system','plfs_monthlyplfs__UR_115_F_6.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','1','3','3','2026','5.9','system',' system','plfs_monthlyplfs__UR_116_D_5.9')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','2','3','3','2026','8.5','system',' system','plfs_monthlyplfs__UR_116_E_8.5')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','2','3','3','3','2026','6.6','system',' system','plfs_monthlyplfs__UR_116_F_6.6')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','1','3','3','2026','14.1','system',' system','plfs_monthlyplfs__UR_117_D_14.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','2','3','3','2026','18.7','system',' system','plfs_monthlyplfs__UR_117_E_18.7')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','2','3','3','3','3','2026','15.3','system',' system','plfs_monthlyplfs__UR_117_F_15.3')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','1','3','3','2026','5.1','system',' system','plfs_monthlyplfs__UR_118_D_5.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','2','3','3','2026','5.4','system',' system','plfs_monthlyplfs__UR_118_E_5.4')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','1','3','3','3','3','2026','5.2','system',' system','plfs_monthlyplfs__UR_118_F_5.2')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','1','3','3','2026','5.1','system',' system','plfs_monthlyplfs__UR_119_D_5.1')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','2','3','3','2026','5.4','system',' system','plfs_monthlyplfs__UR_119_E_5.4')
# insert into plfs_fact(month_code,age_code,sector_code,gender_code,indicator_code,frequency_code,year,indicator_value,created_by,updated_by,plfs_fact_code) values('4','4','3','3','3','3','2026','5.2','system',' system','plfs_monthlyplfs__UR_119_F_5.2')
# Data insert successfully
